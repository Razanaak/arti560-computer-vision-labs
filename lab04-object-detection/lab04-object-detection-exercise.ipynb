# %% [markdown]
# ##### ARTI 560 - Computer Vision
#
# ## Object Detection Using YOLOV8 with KerasCV - Exercise
#
# ### Objective
#
# In this exercise, you wil learn how to use the pre-trained YOLOV8 model from KerasCV to detect objects in images.
#
# You will:
#
# 1. Load the pre-trained YOLOV8 model from KerasCV using the [Pascal VOC preset](https://www.kaggle.com/models/keras/yolov8)
#
# 2. Load 5 images for different classes in [Pascal VOC 2012 dataset](https://datasetninja.com/pascal-voc-2012) and convert it into a NumPy array suitable for the model.
#
# 3. Resize the images before inference to match the model’s expected input size using:
#     ```
#     inference_resizing = keras_cv.layers.Resizing(
#         640, 640, pad_to_aspect_ratio=True, bounding_box_format="xywh"
#     )
#     ```
#
#     **Note:** Resizing ensures that the images fit the model input, maintains aspect ratio, and correctly adjusts bounding boxes.
#
# 4. Run the YOLOV8 detector on each image to predict bounding boxes, class labels, and confidence scores.
#
# 5. Visualize the predictions by drawing the bounding boxes and labels on the images.
#
# 6. Record for each image:
#
#     - Which objects were detected correctly
#
#     - The confidence scores of the detections
#
#     - Any missed or incorrectly labeled objects

# %%
# !pip install tensorflow keras-cv matplotlib
# Out:
# Requirement already satisfied: tensorflow in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (2.20.0)
# Requirement already satisfied: keras-cv in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (0.9.0)
# Requirement already satisfied: matplotlib in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (3.10.8)
# Requirement already satisfied: absl-py>=1.0.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (2.4.2)
# Requirement already satisfied: h5py>=3.11.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: regex in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from keras-cv) (2026.2.28)
# Requirement already satisfied: tensorflow-datasets in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from keras-cv) (4.9.9)
# Requirement already satisfied: keras-core in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from keras-cv) (0.1.7)
# Requirement already satisfied: kagglehub in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from keras-cv) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from keras>=3.10.0->tensorflow) (14.3.2)
# Requirement already satisfied: namex in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from kagglehub->keras-cv) (0.1.16)
# Requirement already satisfied: pyyaml in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from kagglehub->keras-cv) (6.0.3)
# Requirement already satisfied: tqdm in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from kagglehub->keras-cv) (4.67.3)
# Requirement already satisfied: dm-tree in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from keras-core->keras-cv) (0.1.9)
# Requirement already satisfied: attrs>=18.2.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from dm-tree->keras-core->keras-cv) (25.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Requirement already satisfied: etils>=1.9.1 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (1.14.0)
# Requirement already satisfied: immutabledict in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow-datasets->keras-cv) (4.3.1)
# Requirement already satisfied: promise in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: psutil in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow-datasets->keras-cv) (7.2.2)
# Requirement already satisfied: pyarrow in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow-datasets->keras-cv) (23.0.1)
# Requirement already satisfied: simple_parsing in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow-datasets->keras-cv) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow-datasets->keras-cv) (1.17.3)
# Requirement already satisfied: toml in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: einops in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (0.8.2)
# Requirement already satisfied: fsspec in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (2026.2.0)
# Requirement already satisfied: zipp in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (3.23.0)
# Requirement already satisfied: docstring-parser~=0.15 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from simple_parsing->tensorflow-datasets->keras-cv) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.73.0)
# Requirement already satisfied: colorama in C:\Users\HP\anaconda3\envs\cv_lab1\Lib\site-packages (from tqdm->kagglehub->keras-cv) (0.4.6)

# %%
import tensorflow as tf
import keras_cv
import matplotlib.pyplot as plt
import os

# Load the pre-trained YOLOv8 model
model = keras_cv.models.YOLOV8Detector.from_preset(
    "yolo_v8_m_pascalvoc",
    bounding_box_format="xywh"
)
print("Model loaded successfully.")
# Out:
# Downloading to C:\Users\HP\.cache\kagglehub\models\keras\yolov8\keras\yolo_v8_m_pascalvoc\2\config.json...
# 100%|██████████| 2.27k/2.27k [00:00<00:00, 756kB/s]
# Downloading to C:\Users\HP\.cache\kagglehub\models\keras\yolov8\keras\yolo_v8_m_pascalvoc\2\model.weights.h5...
# 100%|██████████| 99.5M/99.5M [00:21<00:00, 4.95MB/s]
# Model loaded successfully.

# %%
import tensorflow as tf
import keras_cv
import os

folder_name = "." 
image_files = ["car.jpg", "bird.jpg", "cat.jpg", "bus.jpg", "dog.jpg"]

processed_images = []


inference_resizing = keras_cv.layers.Resizing(
    640, 640, pad_to_aspect_ratio=True, bounding_box_format="xywh"
)

print("Loading images from the current directory...")
for file_name in image_files:
    image_path = os.path.join(folder_name, file_name)
    
    if os.path.exists(image_path):
       
        raw_image = tf.io.read_file(image_path)
        decoded_image = tf.image.decode_image(raw_image, channels=3)
        image_float = tf.cast(decoded_image, tf.float32)
    
        resized_image = inference_resizing({"images": image_float})["images"]
        processed_images.append(resized_image)
        print(f"Successfully loaded: {file_name}")
    else:
        print(f"File NOT found: {image_path}")

if len(processed_images) == 5:
    image_batch = tf.stack(processed_images)
    print("Batch ready. Shape:", image_batch.shape)
else:
    print(f"Error: Found only {len(processed_images)} images.")
# Out:
# Loading images from the current directory...
# Successfully loaded: car.jpg
# Successfully loaded: bird.jpg
# Successfully loaded: cat.jpg
# Successfully loaded: bus.jpg
# Successfully loaded: dog.jpg
# Batch ready. Shape: (5, 640, 640, 3)

# %%
import matplotlib.pyplot as plt

print("Detecting objects...")
predictions = model.predict(image_batch)
class_mapping = {
    0: 'aeroplane', 1: 'bicycle', 2: 'bird', 3: 'boat', 4: 'bottle',
    5: 'bus', 6: 'car', 7: 'cat', 8: 'chair', 9: 'cow',
    10: 'diningtable', 11: 'dog', 12: 'horse', 13: 'motorbike',
    14: 'person', 15: 'pottedplant', 16: 'sheep', 17: 'sofa',
    18: 'train', 19: 'tvmonitor'
}



keras_cv.visualization.plot_bounding_box_gallery(
    image_batch,
    value_range=(0, 255),
    rows=1,
    cols=5,
    y_pred=predictions,
    scale=5,
    font_scale=0.8,
    bounding_box_format="xywh",
    class_mapping=class_mapping,
)
plt.show()
# Out:
# Detecting objects...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step

# %% [markdown]
# ### Step 6: Observation and Analysis
#
# | Image Name | Object Detected | Confidence Score | Accuracy (Correct/Incorrect) |
# |------------|-----------------|------------------|-----------------------------|
# | car.jpg    | Car             | 0.99             | Correct                     |
# | bird.jpg   | Bird            | 0.99             | Correct                     |
# | cat.jpg    | Cat             | 0.85             | Correct                     |
# |bus.jpg     | bus             | 0.93             | Correct                     |
# | dog.jpg    | Dog             | 0.99             | Correct                     |
